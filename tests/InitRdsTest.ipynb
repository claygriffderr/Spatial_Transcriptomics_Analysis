# %%
source("../initialize_seurat_obj.R")

# %%
library(Seurat)
library(SeuratObject)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: 'SeuratObject'
#
#
# The following objects are masked from 'package:base':
#
#     intersect, t

# %%
home = "C:/Users/grifclay/Desktop/Projects/XeniumSpatialAnalysis/data/Male/20240904_MS_cx"
output = "C:/Users/grifclay/Desktop/Projects/Spatial_Transcriptomics_Analysis/Routput"

fov_name = "FOV"

res = .4

output_name = "Male_Sag_res4"

# %%
obj <- create_Seurat_Obj(home, output, fov_name, res, output_name)
# Out:
# 10X data contains more than one type and is being returned as a list containing matrices of each type.
#
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Warning message:
# "Not validating FOV objects"
# Warning message:
# "Not validating Centroids objects"
# Warning message:
# ...

# %%
DimPlot(obj, label=TRUE)
# Out:
# Error in DimPlot(obj, label = TRUE): could not find function "DimPlot"
# Traceback:
